# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Finding Missing Data**

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna() # true or false -> true if cell value is NaN otherwise false
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
# now find how many NULL values (NaN) in each cell
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any() # check for NULL values (or NaN) in each column
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %% [markdown]
# **Removing Missing Data**

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna(thresh = 1)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df_2 = pd.DataFrame({
    "A": [1, np.nan, np.nan, 4, np.nan, np.nan, 7, np.nan, np.nan, 10, np.nan, np.nan],
    "B": [np.nan, 2, np.nan, np.nan, np.nan, 6, np.nan, 8, np.nan, np.nan, np.nan, 12],
    "C": [np.nan, np.nan, 3, np.nan, 5, np.nan, np.nan, np.nan, 9, np.nan, 11, np.nan]
})
df_2
# Out:
#        A     B     C
# 0    1.0   NaN   NaN
# 1    NaN   2.0   NaN
# 2    NaN   NaN   3.0
# 3    4.0   NaN   NaN
# 4    NaN   NaN   5.0
# 5    NaN   6.0   NaN
# 6    7.0   NaN   NaN
# 7    NaN   8.0   NaN
# 8    NaN   NaN   9.0
# 9   10.0   NaN   NaN
# 10   NaN   NaN  11.0
# 11   NaN  12.0   NaN

# %%
df_2.dropna(thresh = 1)
# Out:
#        A     B     C
# 0    1.0   NaN   NaN
# 1    NaN   2.0   NaN
# 2    NaN   NaN   3.0
# 3    4.0   NaN   NaN
# 4    NaN   NaN   5.0
# 5    NaN   6.0   NaN
# 6    7.0   NaN   NaN
# 7    NaN   8.0   NaN
# 8    NaN   NaN   9.0
# 9   10.0   NaN   NaN
# 10   NaN   NaN  11.0
# 11   NaN  12.0   NaN

# %% [raw]
# Why nothing was dropped?
# -> Every row has at least one non-NaN value, so all rows are kept.

# %%
df_2.dropna(thresh = 2) # thresh=2 → keep rows that have at least 2 non-NaN values
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
df_3 = pd.DataFrame({
    "A": [1,  np.nan, np.nan, 4,  np.nan, 6,  np.nan, 8,  np.nan, 10, np.nan, np.nan],
    "B": [2,  2,      np.nan, np.nan, 5,  np.nan, np.nan, 8,  np.nan, np.nan, 11, np.nan],
    "C": [np.nan, np.nan, 3,  np.nan, 5,  6,  np.nan, np.nan, 9,  np.nan, 11, np.nan]
})
df_3
# Out:
#        A     B     C
# 0    1.0   2.0   NaN
# 1    NaN   2.0   NaN
# 2    NaN   NaN   3.0
# 3    4.0   NaN   NaN
# 4    NaN   5.0   5.0
# 5    6.0   NaN   6.0
# 6    NaN   NaN   NaN
# 7    8.0   8.0   NaN
# 8    NaN   NaN   9.0
# 9   10.0   NaN   NaN
# 10   NaN  11.0  11.0
# 11   NaN   NaN   NaN

# %%
df_3.dropna(thresh = 2)
# Out:
#       A     B     C
# 0   1.0   2.0   NaN
# 4   NaN   5.0   5.0
# 5   6.0   NaN   6.0
# 7   8.0   8.0   NaN
# 10  NaN  11.0  11.0

# %% [markdown]
# **Filling the missing Data**

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(0) # this will replace NaN with 0 (or 0.0 according to condition)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
df.fillna(value = {'A':0,'B':100,"C":300,'D':400})
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  400.0
# 2  0.0  3    3.0  400.0
# 3  4.0  4  300.0  400.0
# 4  5.0  5  300.0    5.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0
